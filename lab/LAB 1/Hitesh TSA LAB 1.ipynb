# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
#read the csv file using pandas
data = pd.read_csv('/content/Month_Value_1 (1).csv')

# %%
# preview the data using head or tail command

# %%
# check data info
data.info
# Out:
# <bound method DataFrame.info of         Period       Revenue  Sales_quantity  Average_cost  \
# 0   01.01.2015  1.601007e+07         12729.0   1257.763541
# 1   01.02.2015  1.580759e+07         11636.0   1358.507000
# 2   01.03.2015  2.204715e+07         15922.0   1384.697024
# 3   01.04.2015  1.881458e+07         15227.0   1235.606705
# 4   01.05.2015  1.402148e+07          8620.0   1626.621765
# ..         ...           ...             ...           ...
# 91  01.08.2022           NaN             NaN           NaN
# 92  01.09.2022           NaN             NaN           NaN
# 93  01.10.2022           NaN             NaN           NaN
# 94  01.11.2022           NaN             NaN           NaN
# 95  01.12.2022           NaN             NaN           NaN
#
#     The_average_annual_payroll_of_the_region
# 0                                 30024676.0
# 1                                 30024676.0
# 2                                 30024676.0
# ...

# %%
data.describe()
# Out:
#             Revenue  Sales_quantity  Average_cost  \
# count  6.400000e+01       64.000000     64.000000
# mean   3.236045e+07    19197.375000   1695.061159
# std    1.164150e+07     6591.287257    296.844793
# min    1.402148e+07     8314.000000   1110.576805
# 25%    2.242655e+07    15065.500000   1499.142841
# 50%    3.209088e+07    18368.000000   1654.399798
# 75%    3.992999e+07    22856.250000   1916.401096
# max    5.875647e+07    38069.000000   2559.328184
#
#        The_average_annual_payroll_of_the_region
# count                              6.400000e+01
# mean                               2.869083e+07
# std                                1.057191e+06
# min                                2.740647e+07
# 25%                                2.782857e+07
# 50%                                2.819785e+07
# 75%                                2.987852e+07
# max                                3.002468e+07

# %%
# check the number of unique values in the period column

data.Period.unique()
# Out:
# array(['01.01.2015', '01.02.2015', '01.03.2015', '01.04.2015',
#        '01.05.2015', '01.06.2015', '01.07.2015', '01.08.2015',
#        '01.09.2015', '01.10.2015', '01.11.2015', '01.12.2015',
#        '01.01.2016', '01.02.2016', '01.03.2016', '01.04.2016',
#        '01.05.2016', '01.06.2016', '01.07.2016', '01.08.2016',
#        '01.09.2016', '01.10.2016', '01.11.2016', '01.12.2016',
#        '01.01.2017', '01.02.2017', '01.03.2017', '01.04.2017',
#        '01.05.2017', '01.06.2017', '01.07.2017', '01.08.2017',
#        '01.09.2017', '01.10.2017', '01.11.2017', '01.12.2017',
#        '01.01.2018', '01.02.2018', '01.03.2018', '01.04.2018',
#        '01.05.2018', '01.06.2018', '01.07.2018', '01.08.2018',
#        '01.09.2018', '01.10.2018', '01.11.2018', '01.12.2018',
#        '01.01.2019', '01.02.2019', '01.03.2019', '01.04.2019',
#        '01.05.2019', '01.06.2019', '01.07.2019', '01.08.2019',
#        '01.09.2019', '01.10.2019', '01.11.2019', '01.12.2019',
# ...

# %%
# if there is any null value then calculate the sum of it

data.isnull().sum().sum()
# Out:
# 128

# %%
# preview the data to see the presence of null values in that dataset

data.isnull().values.any()
# Out:
# True

# %%
# check where are the null values present in the datasets

data.isnull().values
# Out:
# array([[False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
# ...

# %%
# remove the rows that has those null values

data.dropna()
# Out:
#         Period       Revenue  Sales_quantity  Average_cost  \
# 0   01.01.2015  1.601007e+07         12729.0   1257.763541
# 1   01.02.2015  1.580759e+07         11636.0   1358.507000
# 2   01.03.2015  2.204715e+07         15922.0   1384.697024
# 3   01.04.2015  1.881458e+07         15227.0   1235.606705
# 4   01.05.2015  1.402148e+07          8620.0   1626.621765
# ..         ...           ...             ...           ...
# 59  01.12.2019  5.875647e+07         38069.0   1543.420464
# 60  01.01.2020  5.628830e+07         27184.0   2070.640850
# 61  01.02.2020  4.022524e+07         23509.0   1711.057181
# 62  01.03.2020  5.002217e+07         32569.0   1535.882748
# 63  01.04.2020  5.232069e+07         26615.0   1965.834790
#
#     The_average_annual_payroll_of_the_region
# 0                                 30024676.0
# 1                                 30024676.0
# 2                                 30024676.0
# 3                                 30024676.0
# ...

# %% [markdown]
# We have been given revenue values for continuous 64 months, we have to predict for 32 months

# %%
#convert dates in a DataFrame to Pandas datetime or Period objects with a specific frequency
data['Period']=pd.to_datetime(data['Period'],format="%d.%m.%Y")
data['Period']=data['Period'].dt.to_period('M')

# %%
# get data infor
data.info
# Out:
# <bound method DataFrame.info of      Period       Revenue  Sales_quantity  Average_cost  \
# 0   2015-01  1.601007e+07         12729.0   1257.763541
# 1   2015-02  1.580759e+07         11636.0   1358.507000
# 2   2015-03  2.204715e+07         15922.0   1384.697024
# 3   2015-04  1.881458e+07         15227.0   1235.606705
# 4   2015-05  1.402148e+07          8620.0   1626.621765
# ..      ...           ...             ...           ...
# 91  2022-08           NaN             NaN           NaN
# 92  2022-09           NaN             NaN           NaN
# 93  2022-10           NaN             NaN           NaN
# 94  2022-11           NaN             NaN           NaN
# 95  2022-12           NaN             NaN           NaN
#
#     The_average_annual_payroll_of_the_region
# 0                                 30024676.0
# 1                                 30024676.0
# 2                                 30024676.0
# 3                                 30024676.0
# ...

# %%
ts=data.loc[0:63,['Period','Revenue','Sales_quantity']]
ts
# Out:
#      Period       Revenue  Sales_quantity
# 0   2015-01  1.601007e+07         12729.0
# 1   2015-02  1.580759e+07         11636.0
# 2   2015-03  2.204715e+07         15922.0
# 3   2015-04  1.881458e+07         15227.0
# 4   2015-05  1.402148e+07          8620.0
# ..      ...           ...             ...
# 59  2019-12  5.875647e+07         38069.0
# 60  2020-01  5.628830e+07         27184.0
# 61  2020-02  4.022524e+07         23509.0
# 62  2020-03  5.002217e+07         32569.0
# 63  2020-04  5.232069e+07         26615.0
#
# [64 rows x 3 columns]

# %%
#extract the month and year from dates in a DataFrame
ts['Month']=ts['Period'].dt.month
ts['Year']=ts['Period'].dt.year
ts.head()
# Out:
#     Period       Revenue  Sales_quantity  Month  Year
# 0  2015-01  1.601007e+07         12729.0      1  2015
# 1  2015-02  1.580759e+07         11636.0      2  2015
# 2  2015-03  2.204715e+07         15922.0      3  2015
# 3  2015-04  1.881458e+07         15227.0      4  2015
# 4  2015-05  1.402148e+07          8620.0      5  2015

# %%
ts.set_index('Period',inplace=True)
ts.head()
# Out:
#               Revenue  Sales_quantity  Month  Year
# Period
# 2015-01  1.601007e+07         12729.0      1  2015
# 2015-02  1.580759e+07         11636.0      2  2015
# 2015-03  2.204715e+07         15922.0      3  2015
# 2015-04  1.881458e+07         15227.0      4  2015
# 2015-05  1.402148e+07          8620.0      5  2015

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.title('Revenue Data')
ts['Revenue'].plot()
# Out:
# <Axes: title={'center': 'Revenue Data'}, xlabel='Period'>

# %%
sns.lineplot(x='Month',y='Revenue',data=ts)
# Out:
# <Axes: xlabel='Month', ylabel='Revenue'>

# %%
sns.boxplot(x='Month',y='Revenue',data=ts)
# Out:
# <Axes: xlabel='Month', ylabel='Revenue'>

# %% [markdown]
# It points toward seasonal pattern

# %%
sns.lineplot(x='Year',y='Revenue',data=ts)
# Out:
# <Axes: xlabel='Year', ylabel='Revenue'>

# %%
sns.boxplot(x='Year',y='Revenue',data=ts)
# Out:
# <Axes: xlabel='Year', ylabel='Revenue'>

# %% [markdown]
# This shows there is linearly increasing trend

# %%
plt.title('Sales Data')
ts['Sales_quantity'].plot()
# Out:
# <Axes: title={'center': 'Sales Data'}, xlabel='Period'>

# %%
sns.lineplot(x='Month',y='Sales_quantity',data=ts)
# Out:
# <Axes: xlabel='Month', ylabel='Sales_quantity'>

# %%
sns.boxplot(x='Month',y='Sales_quantity',data=ts)
# Out:
# <Axes: xlabel='Month', ylabel='Sales_quantity'>

# %% [markdown]
# It points toward seasonal pattern

# %%
sns.lineplot(x='Year',y='Sales_quantity',data=ts)
# Out:
# <Axes: xlabel='Year', ylabel='Sales_quantity'>

# %%
sns.boxplot(x='Year',y='Sales_quantity',data=ts)
# Out:
# <Axes: xlabel='Year', ylabel='Sales_quantity'>
